# %% [markdown]
# # Logbook

# %% [markdown]
# Why do I have more $\ge 2.0$ than $\le-2.0$ in the test data?

# %% [markdown]
# ### using eta_true_noise
# noise 0.0
# - mean((η_pred .- η_approx) .^ 2) = 0.23834701f0
# - mean((η_pred .- η_true) .^ 2) = 0.39933606425784157
# - mean((η_approx .- η_true) .^ 2) = 0.30481571565561394
# - mean((η_pred .- zeros(size(η_pred))) .^ 2) = 0.44914620858153076
# - mean((η_approx .- zeros(size(η_pred))) .^ 2) = 0.6770966996105874
# - mean((η_true .- zeros(size(η_pred))) .^ 2) = 0.9999978139640632
# - mean(η_pred) = -0.060941216f0
# - var(η_pred) = 0.44543388f0
# - mean(η_approx) = -0.052940167f0
# - var(η_approx) = 0.67429626f0
# - mean(η_true) = -0.0010711196928351945
# - var(η_true) = 1.0
# - 1431.651685 seconds (113.28 M allocations: 80.173 GiB, 0.42% gc time, 0.00% compilation time)
#
# ---
#
# - idx: 6250                                                                                                                          │···
# - mean((η_pred .- η_approx) .^ 2) = 0.23834701f0                                                                                     │···
# - mean((η_pred .- η_true) .^ 2) = 0.39933606425784157                                                                                │···
# - mean((η_approx .- η_true) .^ 2) = 0.30481571565561394                                                                              │···
# - mean((η_pred .- zeros(size(η_pred))) .^ 2) = 0.44914620858153076                                                                   │···
# - mean((η_approx .- zeros(size(η_pred))) .^ 2) = 0.6770966996105874                                                                  │···
# - mean((η_true .- zeros(size(η_pred))) .^ 2) = 0.9999978139640632                                                                    │···
# - mean(η_pred) = -0.060941216f0                                                                                                      │···
# - var(η_pred) = 0.44543388f0                                                                                                         │···
# - mean(η_approx) = -0.052940167f0                                                                                                    │···
# - var(η_approx) = 0.67429626f0                                                                                                       │···
# - mean(η_true) = -0.0010711196928351945                                                                                              │···
# - var(η_true) = 1.0                                                                                                                  │···
# - get_bootstrap(η_pred, η_approx) = ((0.23834701f0, 0.2367986250668764, 0.23967593163251877),)                                       │···
# - get_bootstrap(η_pred, η_true) = ((0.39933606425784157, 0.39714318226255485, 0.4016210932160685),)                                  │···
# - get_bootstrap(η_approx, η_true) = ((0.30481571565561394, 0.3023487901169467, 0.30749596857968553),)                                │···
# - get_bootstrap(η_pred, zeros(size(η_pred))) = ((0.44914620858153076, 0.44690224731242856, 0.4511952312220842),)                     │···
# - get_bootstrap(η_pred, randn(size(η_pred))) = ((1.4502363267400873, 1.443049882194329, 1.4575875373871503),)                        │···
# - get_bootstrap(η_approx, zeros(size(η_pred))) = ((0.6770966996105874, 0.6735763428215181, 0.6807946136805189),)                     │···
# - get_bootstrap(η_approx, randn(size(η_pred))) = ((1.676540699615621, 1.6677649637779093, 1.6850729395089774),)                      │···
# - get_bootstrap(η_true, zeros(size(η_pred))) = ((0.9999978139640632, 0.9944942542808837, 1.0049863632521459),)                       │···
# - get_bootstrap(η_true, randn(size(η_pred))) = ((2.0034641332112306, 1.9938489165541524, 2.013557104912598),)                        │···
# - r_squared_pred = 0.6006626046175072                                                                                                │···
# - r_squared_approx = 0.6951832682886137                                                                                              │···
# - 557.953415 seconds (2.77 G allocations: 351.383 GiB, 6.80% gc time)
#
# ---
# ---

# %% [markdown]
# noise 1.0
# - mean((η_pred .- η_approx) .^ 2) = 0.46912363f0
# - mean((η_pred .- η_true) .^ 2) = 0.6982696937050947
# - mean((η_approx .- η_true) .^ 2) = 0.3044123893276315
# - mean((η_pred .- zeros(size(η_pred))) .^ 2) = 0.21398752563488244
# - mean((η_approx .- zeros(size(η_pred))) .^ 2) = 0.6770286001997542
# - mean((η_true .- zeros(size(η_pred))) .^ 2) = 1.0000015375629423
# - mean(η_pred) = -0.049074285f0
# - var(η_pred) = 0.21157995f0
# - mean(η_approx) = -0.05285349f0
# - var(η_approx) = 0.6742374f0
# - mean(η_true) = -0.002207010710352343
# - var(η_true) = 1.0
#
# ---
#
# - idx: 6250                                                                                                                          │···
# - mean((η_pred .- η_approx) .^ 2) = 0.46912363f0                                                                                     │···
# - mean((η_pred .- η_true) .^ 2) = 0.6982696937050947                                                                                 │···
# - mean((η_approx .- η_true) .^ 2) = 0.3044123893276315                                                                               │···
# - mean((η_pred .- zeros(size(η_pred))) .^ 2) = 0.21398752563488244                                                                   │···
# - mean((η_approx .- zeros(size(η_pred))) .^ 2) = 0.6770286001997542                                                                  │···
# - mean((η_true .- zeros(size(η_pred))) .^ 2) = 1.0000015375629423                                                                    │···mean(η_pred) = -0.049074285f0                                                                                                      │···
# - var(η_pred) = 0.21157995f0                                                                                                         │···mean(η_approx) = -0.05285349f0                                                                                                     │···
# - var(η_approx) = 0.6742374f0                                                                                                        │···mean(η_true) = -0.002207010710352343                                                                                               │···
# - var(η_true) = 1.0                                                                                                                  │···get_bootstrap(η_pred, η_approx) = ((0.46912363f0, 0.4666642643511295, 0.47148861512541773),)                                       │···
# - get_bootstrap(η_pred, η_true) = ((0.6982696937050947, 0.6945572045529317, 0.7020270887502533),)                                    │···
# - get_bootstrap(η_approx, η_true) = ((0.3044123893276315, 0.30167450548747093, 0.3069633058231307),)                                 │···
# - get_bootstrap(η_pred, zeros(size(η_pred))) = ((0.21398752563488244, 0.21291086752905844, 0.21508848414170853),)                    │···
# - get_bootstrap(η_pred, randn(size(η_pred))) = ((1.2132577462871215, 1.2078365085429754, 1.2199859689391328),)                       │···
# - get_bootstrap(η_approx, zeros(size(η_pred))) = ((0.6770286001997542, 0.6737283880905129, 0.6803787008858401),)                     │···
# - get_bootstrap(η_approx, randn(size(η_pred))) = ((1.6816896439437494, 1.6730758470982159, 1.689718830928547),)                      │···
# - get_bootstrap(η_true, zeros(size(η_pred))) = ((1.0000015375629423, 0.994594712968496, 1.0050349236799443),)                        │···
# - get_bootstrap(η_true, randn(size(η_pred))) = ((1.9976215662073775, 1.9868108591774498, 2.007277747875892),)                        │···
# - r_squared_pred = 0.3017279787215009                                                                                                │···
# - r_squared_approx = 0.6955865959610217                                                                                              │···
# - 564.412882 seconds (2.77 G allocations: 351.383 GiB, 6.63% gc time)
#
# ---
# ---

# %% [markdown]
# noise 9.0
#
# - mean((η_pred .- η_approx) .^ 2) = 0.5720291f0
# - mean((η_pred .- η_true) .^ 2) = 0.945633085523486
# - mean((η_approx .- η_true) .^ 2) = 0.30520710572419324
# - mean((η_pred .- zeros(size(η_pred))) .^ 2) = 0.04291834576447331
# - mean((η_approx .- zeros(size(η_pred))) .^ 2) = 0.6111444207602481
# - mean((η_true .- zeros(size(η_pred))) .^ 2) = 0.9999994443121288
# - mean(η_pred) = -0.050398946f0
# - var(η_pred) = 0.04037843f0
# - mean(η_approx) = -0.051836543f0
# - var(η_approx) = 0.6084594f0
# - mean(η_true) = -0.0016666269714758384
# - var(η_true) = 1.0
# - 307.144362 seconds (69.93 M allocations: 77.390 GiB, 1.61% gc time)
#
# ---
# -
# - idx: 6250                                                                                                                          │···
# - mean((η_pred .- η_approx) .^ 2) = 0.5720291f0                                                                                      │···
# - mean((η_pred .- η_true) .^ 2) = 0.945633085523486                                                                                  │···
# - mean((η_approx .- η_true) .^ 2) = 0.30520710572419324                                                                              │···
# - mean((η_pred .- zeros(size(η_pred))) .^ 2) = 0.04291834576447331                                                                   │···
# - mean((η_approx .- zeros(size(η_pred))) .^ 2) = 0.6111444207602481                                                                  │···
# - mean((η_true .- zeros(size(η_pred))) .^ 2) = 0.9999994443121288                                                                    │···mean(η_pred) = -0.050398946f0                                                                                                      │···
# - var(η_pred) = 0.04037843f0                                                                                                         │···mean(η_approx) = -0.051836543f0                                                                                                    │···
# - var(η_approx) = 0.6084594f0                                                                                                        │···mean(η_true) = -0.0016666269714758384                                                                                              │···
# - var(η_true) = 1.0                                                                                                                  │···get_bootstrap(η_pred, η_approx) = ((0.5720291f0, 0.5691861867904663, 0.575011071562767),)                                          │···
# - get_bootstrap(η_pred, η_true) = ((0.945633085523486, 0.9407963798612945, 0.9504154885170071),)                                     │···
# - get_bootstrap(η_approx, η_true) = ((0.30520710572419324, 0.30288684232333524, 0.30752217708527846),)                               │···
# - get_bootstrap(η_pred, zeros(size(η_pred))) = ((0.04291834576447331, 0.0426810384151935, 0.04314405611879714),)                     │···
# - get_bootstrap(η_pred, randn(size(η_pred))) = ((1.0371601253962477, 1.0315235869140216, 1.0424349021333936),)                       │···
# - get_bootstrap(η_approx, zeros(size(η_pred))) = ((0.6111444207602481, 0.6080680654322396, 0.614126487697932),)                      │···
# - get_bootstrap(η_approx, randn(size(η_pred))) = ((1.6055632415651646, 1.5977082604718136, 1.613202361224742),)                      │···
# - get_bootstrap(η_true, zeros(size(η_pred))) = ((0.9999994443121288, 0.9947499639582491, 1.0051567352705402),)                       │···
# - get_bootstrap(η_true, randn(size(η_pred))) = ((2.002882955212472, 1.9932267693929355, 2.0128156926684806),)                        │···
# - r_squared_pred = 0.05436376235572182                                                                                               │···
# - r_squared_approx = 0.6947918769153965                                                                                              │···
# - 564.136958 seconds (2.77 G allocations: 351.383 GiB, 6.41% gc time)
#
# ---
# ---

# %% [markdown]
# noise 18.0
#
# - mean((η_pred .- η_approx) .^ 2) = 0.65195227f0
# - mean((η_pred .- η_true) .^ 2) = 0.9728976137531995
# - mean((η_approx .- η_true) .^ 2) = 0.30345558005353873
# - mean((η_pred .- zeros(size(η_pred))) .^ 2) = 0.021364032675201098
# - mean((η_approx .- zeros(size(η_pred))) .^ 2) = 0.675781623239588
# - mean((η_true .- zeros(size(η_pred))) .^ 2) = 1.0000038534494462
# - mean(η_pred) = -0.04603417f0
# - var(η_pred) = 0.019244954f0
# - mean(η_approx) = -0.052982852f0
# - var(η_approx) = 0.6729767f0
# - mean(η_true) = -0.002680817558078297
# - var(η_true) = 0.9999999999999998
# - 305.230198 seconds (69.93 M allocations: 77.390 GiB, 1.47% gc time)
#
# - ---
# - idx: 6250                                                                                                                          │···
# - mean((η_pred .- η_approx) .^ 2) = 0.65195227f0                                                                                     │···
# - mean((η_pred .- η_true) .^ 2) = 0.9728976137531995                                                                                 │···
# - mean((η_approx .- η_true) .^ 2) = 0.30345558005353873                                                                              │···
# - mean((η_pred .- zeros(size(η_pred))) .^ 2) = 0.021364032675201098                                                                  │···
# - mean((η_approx .- zeros(size(η_pred))) .^ 2) = 0.675781623239588                                                                   │···
# - mean((η_true .- zeros(size(η_pred))) .^ 2) = 1.0000038534494462                                                                    │···mean(η_pred) = -0.04603417f0                                                                                                       │···
# - var(η_pred) = 0.019244954f0                                                                                                        │···mean(η_approx) = -0.052982852f0                                                                                                    │···
# - var(η_approx) = 0.6729767f0                                                                                                        │···mean(η_true) = -0.002680817558078297                                                                                               │···
# - var(η_true) = 0.9999999999999998                                                                                                   │···get_bootstrap(η_pred, η_approx) = ((0.65195227f0, 0.6486082628369332, 0.655329667031765),)                                         │···
# - get_bootstrap(η_pred, η_true) = ((0.9728976137531995, 0.9677880040392062, 0.9777715797616547),)                                    │···
# - get_bootstrap(η_approx, η_true) = ((0.30345558005353873, 0.30078592047935465, 0.3059107687879947),)                                │···
# - get_bootstrap(η_pred, zeros(size(η_pred))) = ((0.021364032675201098, 0.021268625031009212, 0.02145940379071209),)                  │···
# - get_bootstrap(η_pred, randn(size(η_pred))) = ((1.0215627236531462, 1.0168481451913187, 1.027110178965221),)                        │···
# - get_bootstrap(η_approx, zeros(size(η_pred))) = ((0.675781623239588, 0.6722876701685342, 0.679074808331563),)                       │···
# - get_bootstrap(η_approx, randn(size(η_pred))) = ((1.6729916608375466, 1.66437554631256, 1.6809230479189337),)                       │···
# - get_bootstrap(η_true, zeros(size(η_pred))) = ((1.0000038534494462, 0.9947245028592346, 1.0044838950640158),)                       │···
# - get_bootstrap(η_true, randn(size(η_pred))) = ((1.9952392987553413, 1.9852073202150176, 2.005733149964838),)                        │···
# - r_squared_pred = 0.02709914324394469                                                                                               │···
# - r_squared_approx = 0.6965434084244894                                                                                              │···
# - 553.500083 seconds (2.77 G allocations: 351.383 GiB, 6.34% gc time)
#
# ---
# ---

# %% [markdown]
# noise 49.0
#
# - mean((η_pred .- η_approx) .^ 2) = 0.6656595f0
# - mean((η_pred .- η_true) .^ 2) = 0.9935954450305963
# - mean((η_approx .- η_true) .^ 2) = 0.30493676666968705
# - mean((η_pred .- zeros(size(η_pred))) .^ 2) = 0.011760009442602904
# - mean((η_approx .- zeros(size(η_pred))) .^ 2) = 0.6767864975845942
# - mean((η_true .- zeros(size(η_pred))) .^ 2) = 1.0000053575111452
# - mean(η_pred) = -0.05291169f0
# - var(η_pred) = 0.008960391f0
# - mean(η_approx) = -0.052943848f0
# - var(η_approx) = 0.67398566f0
# - mean(η_true) = -0.002948023825978472
# - var(η_true) = 1.0
# - 304.448623 seconds (69.93 M allocations: 77.390 GiB, 1.49% gc time
#
# ---
# - idx: 6250                                                                                                                          │·········
# - mean((η_pred .- η_approx) .^ 2) = 0.6656595f0                                                                                      │·········
# - mean((η_pred .- η_true) .^ 2) = 0.9935954450305963                                                                                 │·········
# - mean((η_approx .- η_true) .^ 2) = 0.30493676666968705                                                                              │·········
# - mean((η_pred .- zeros(size(η_pred))) .^ 2) = 0.011760009442602904                                                                  │·········
# - mean((η_approx .- zeros(size(η_pred))) .^ 2) = 0.6767864975845942                                                                  │·········
# - mean((η_true .- zeros(size(η_pred))) .^ 2) = 1.0000053575111452                                                                    │·········
# - mean(η_pred) = -0.05291169f0                                                                                                       │·········
# - var(η_pred) = 0.008960391f0                                                                                                        │·········
# - mean(η_approx) = -0.052943848f0                                                                                                    │·········
# - var(η_approx) = 0.67398566f0                                                                                                       │·········mean(η_true) = -0.002948023825978472                                                                                               │·········
# - var(η_true) = 1.0                                                                                                                  │·········get_bootstrap(η_pred, η_approx) = ((0.6656595f0, 0.6622358754277229, 0.6686779156327247),)                                         │·········
# - get_bootstrap(η_pred, η_true) = ((0.9935954450305963, 0.9886640383776295, 0.9983331700774678),)                                    │·········get_bootstrap(η_approx, η_true) = ((0.30493676666968705, 0.30235434880654244, 0.3076790011467654),)                                │·········
# - get_bootstrap(η_pred, zeros(size(η_pred))) = ((0.011760009442602904, 0.011704617212834816, 0.011816754742485473),)                 │·········
# - get_bootstrap(η_pred, randn(size(η_pred))) = ((1.0141962629996197, 1.0089371450179805, 1.0192726785671626),)                       │·········
# - get_bootstrap(η_approx, zeros(size(η_pred))) = ((0.6767864975845942, 0.6732706487622858, 0.6801113770465677),)                     │·········
# - get_bootstrap(η_approx, randn(size(η_pred))) = ((1.6737495630285633, 1.6648985268206062, 1.682543249500528),)                      │·········
# - get_bootstrap(η_true, zeros(size(η_pred))) = ((1.0000053575111452, 0.9951035133515578, 1.0047755828849394),)                       │·········
# - get_bootstrap(η_true, randn(size(η_pred))) = ((1.9967016027995452, 1.9865983780336673, 2.0065477351832675),)                       │·········
# - r_squared_pred = 0.006401242973546939                                                                                              │·········
# - r_squared_approx = 0.6950622168710359                                                                                              │·········
# - 578.860665 seconds (2.77 G allocations: 351.618 GiB, 6.21% gc time)
